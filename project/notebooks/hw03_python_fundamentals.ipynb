# %% [markdown]
# # Stage 03 — Python Fundamentals

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print("Original array:", arr)
print("Add 5:", arr + 5)
print("Multiply by 2:", arr * 2)
print("Squared:", arr ** 2)
# Out:
# Original array: [1 2 3 4 5]
# Add 5: [ 6  7  8  9 10]
# Multiply by 2: [ 2  4  6  8 10]
# Squared: [ 1  4  9 16 25]

# %%
# Loop method
loop_result = []

for x in arr:
    loop_result.append(int(x * 2))

print("Loop result:", loop_result)

# Vectorized method
vectorized_result = arr * 2

print("Vectorized result:", vectorized_result)
# Out:
# Loop result: [2, 4, 6, 8, 10]
# Vectorized result: [ 2  4  6  8 10]

# %% [markdown]
# **Comparison:** Both methods produce the same result, but the vectorized NumPy approach is more concise and is generally more efficient for large arrays.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/starter_data.csv")

df.head()
# Out:
#   category  value        date
# 0        A     10  2025-08-01
# 1        B     15  2025-08-02
# 2        A     12  2025-08-03
# 3        B     18  2025-08-04
# 4        C     25  2025-08-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  10 non-null     object
#  1   value     10 non-null     int64
#  2   date      10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 368.0+ bytes

# %%
df.describe()
# Out:
#            value
# count  10.000000
# mean   17.600000
# std     7.381659
# min    10.000000
# 25%    12.250000
# 50%    14.500000
# 75%    23.250000
# max    30.000000

# %%
df.groupby("category")["value"].mean()
# Out:
# category
# A    11.500000
# B    15.666667
# C    27.666667
# Name: value, dtype: float64

# %%
summary_stats = df.describe()

summary_stats.to_csv("../data/processed/summary.csv")

# %%
# def get_summary_stats(df):
#     return df.describe()

# %%
# get_summary_stats(df)

# %%
df.isna().sum()
# Out:
# category    0
# value       0
# date        0
# dtype: int64

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.utils import get_summary_stats

# %%
get_summary_stats(df)
# Out:
#            value
# count  10.000000
# mean   17.600000
# std     7.381659
# min    10.000000
# 25%    12.250000
# 50%    14.500000
# 75%    23.250000
# max    30.000000

# %%
group_mean = df.groupby("category")["value"].mean()

group_mean.plot(kind="bar")
# Out:
# <Axes: xlabel='category'>

# %%
import matplotlib.pyplot as plt

ax = group_mean.plot(kind="bar")

ax.set_title("Average Value by Category")
ax.set_xlabel("Category")
ax.set_ylabel("Average Value")

plt.tight_layout()
plt.savefig("../data/processed/category_mean_plot.png")
plt.show()
